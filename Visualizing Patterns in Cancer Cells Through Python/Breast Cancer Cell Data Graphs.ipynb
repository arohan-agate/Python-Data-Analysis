# %%
# target = 1.0 (or class 1) displays the malignant cells
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
cancer

import warnings
warnings.filterwarnings('ignore')

# %%
# target = 1.0 (or class 1) displays the malignant cells
df_cancer = pd.DataFrame(np.c_[cancer['data'], cancer['target']], columns = np.append(cancer['feature_names'], ['target']))
df_cancer
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
# target = 1.0 (or class 1) displays the malignant cells
# scatter plot between mean area and mean smoothness
plt.figure(figsize = (10,10))

sns.scatterplot(x = 'mean area', y = 'mean smoothness', data = df_cancer, hue = 'target').set(title='Relationship between the mean area and the mean smoothness')
# Out:
# [Text(0.5, 1.0, 'Relationship between the mean area and the mean smoothness')]

# %%
# target = 1.0 (or class 1) displays the malignant cells
# prints out countplot to know how many samples belong to class #0 and #1
plt.figure(figsize = (10,10))
sns.countplot(df_cancer['target'], label = "Count").set(title='number of benign cells (class 0.0) vs. number of malignant cells (class 1.0)')
# Out:
# [Text(0.5, 1.0, 'number of benign cells (class 0.0) vs. number of malignant cells (class 1.0)')]

# %%
# target = 1.0 (or class 1) displays the malignant cells
# scatterplot between the mean radius and mean area

plt.figure(figsize = (10,10))
sns.scatterplot(x = 'mean radius', y = 'mean area', data = df_cancer, hue = 'target').set(title='Relationship between the mean radius and mean area')
# Out:
# [Text(0.5, 1.0, 'Relationship between the mean radius and mean area')]

# %%
# target = 1.0 (or class 1) displays the malignant cells
# relationship between benign and malignant cells when it comes to radius, texture, area, perimeter, and smoothness
sns.pairplot(df_cancer, hue = 'target', vars = ['mean radius', 'mean texture', 'mean area', 'mean perimeter', 'mean smoothness'])

# %%
# target = 1.0 (or class 1) displays the malignant cells
# Strong correlation between the mean radius and mean perimeter, mean area and mean primeter
plt.figure(figsize = (30, 30)) 
sns.heatmap(df_cancer.corr(), annot = True).set(title='Correlation between all breast cancer cell measurables')
# Out:
# [Text(0.5, 1.0, 'Correlation between all breast cancer cell measurables')]

# %%
# target = 1.0 (or class 1) displays the malignant cells
# distplot between benign and malignant cells, displays distribution and average radius

class_0_df = df_cancer[df_cancer['target'] == 0]
class_1_df = df_cancer[df_cancer['target'] == 1]

plt.figure(figsize = (10, 7))
sns.distplot(class_0_df['mean radius'], bins = 25, color = 'b')
sns.distplot(class_1_df['mean radius'], bins = 25, color = 'r').set(title = 'Relationship between benign and malignant cells, displays the average radius')
plt.grid()
